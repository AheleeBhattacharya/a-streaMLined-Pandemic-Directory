# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
sns.set()

# %%
# load the dataset
data_orig = pd.read_csv('https://covid.ourworldindata.org/data/owid-covid-data.csv')

# %%
data_orig.head()
# Out:
#   iso_code continent  ... human_development_index excess_mortality
# 0      AFG      Asia  ...                   0.511              NaN
# 1      AFG      Asia  ...                   0.511              NaN
# 2      AFG      Asia  ...                   0.511              NaN
# 3      AFG      Asia  ...                   0.511              NaN
# 4      AFG      Asia  ...                   0.511              NaN
#
# [5 rows x 62 columns]

# %%
data_orig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109316 entries, 0 to 109315
# Data columns (total 62 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   iso_code                               109316 non-null  object
#  1   continent                              104260 non-null  object
#  2   location                               109316 non-null  object
#  3   date                                   109316 non-null  object
#  4   total_cases                            104624 non-null  float64
#  5   new_cases                              104621 non-null  float64
#  6   new_cases_smoothed                     103611 non-null  float64
#  7   total_deaths                           94190 non-null   float64
#  8   new_deaths                             94345 non-null   float64
#  9   new_deaths_smoothed                    103611 non-null  float64
#  10  total_cases_per_million                104070 non-null  float64
#  11  new_cases_per_million                  104067 non-null  float64
#  12  new_cases_smoothed_per_million         103062 non-null  float64
#  13  total_deaths_per_million               93649 non-null   float64
#  14  new_deaths_per_million                 93804 non-null   float64
#  15  new_deaths_smoothed_per_million        103062 non-null  float64
#  16  reproduction_rate                      87962 non-null   float64
#  17  icu_patients                           11812 non-null   float64
#  18  icu_patients_per_million               11812 non-null   float64
#  19  hosp_patients                          14194 non-null   float64
#  20  hosp_patients_per_million              14194 non-null   float64
#  21  weekly_icu_admissions                  1037 non-null    float64
#  22  weekly_icu_admissions_per_million      1037 non-null    float64
#  23  weekly_hosp_admissions                 2010 non-null    float64
#  24  weekly_hosp_admissions_per_million     2010 non-null    float64
#  25  new_tests                              48430 non-null   float64
#  26  total_tests                            48142 non-null   float64
#  27  total_tests_per_thousand               48142 non-null   float64
#  28  new_tests_per_thousand                 48430 non-null   float64
#  29  new_tests_smoothed                     56876 non-null   float64
#  30  new_tests_smoothed_per_thousand        56876 non-null   float64
#  31  positive_rate                          53215 non-null   float64
#  32  tests_per_case                         52583 non-null   float64
#  33  tests_units                            58670 non-null   object
#  34  total_vaccinations                     21628 non-null   float64
#  35  people_vaccinated                      20703 non-null   float64
#  36  people_fully_vaccinated                17723 non-null   float64
#  37  total_boosters                         167 non-null     float64
#  38  new_vaccinations                       17963 non-null   float64
#  39  new_vaccinations_smoothed              38099 non-null   float64
#  40  total_vaccinations_per_hundred         21628 non-null   float64
#  41  people_vaccinated_per_hundred          20703 non-null   float64
#  42  people_fully_vaccinated_per_hundred    17723 non-null   float64
#  43  total_boosters_per_hundred             167 non-null     float64
#  44  new_vaccinations_smoothed_per_million  38099 non-null   float64
#  45  stringency_index                       90696 non-null   float64
#  46  population                             108597 non-null  float64
#  47  population_density                     101344 non-null  float64
#  48  median_age                             97189 non-null   float64
#  49  aged_65_older                          96103 non-null   float64
#  50  aged_70_older                          96654 non-null   float64
#  51  gdp_per_capita                         97612 non-null   float64
#  52  extreme_poverty                        65682 non-null   float64
#  53  cardiovasc_death_rate                  97524 non-null   float64
#  54  diabetes_prevalence                    100231 non-null  float64
#  55  female_smokers                         76195 non-null   float64
#  56  male_smokers                           75083 non-null   float64
#  57  handwashing_facilities                 48983 non-null   float64
#  58  hospital_beds_per_thousand             88735 non-null   float64
#  59  life_expectancy                        103748 non-null  float64
#  60  human_development_index                97621 non-null   float64
#  61  excess_mortality                       3874 non-null    float64
# dtypes: float64(57), object(5)
# memory usage: 51.7+ MB

# %%
data_orig.describe()
# Out:
#         total_cases      new_cases  ...  human_development_index  excess_mortality
# count  1.046240e+05  104621.000000  ...             97621.000000       3874.000000
# mean   1.228519e+06    6241.063477  ...                 0.726944         18.202006
# std    8.311770e+06   38464.912460  ...                 0.150297         35.407299
# min    1.000000e+00  -74347.000000  ...                 0.394000        -95.590000
# 25%    1.556000e+03       2.000000  ...                 0.602000          0.560000
# 50%    1.637850e+04      80.000000  ...                 0.744000          7.605000
# 75%    1.726535e+05     862.000000  ...                 0.848000         23.985000
# max    2.062545e+08  905993.000000  ...                 0.957000        410.620000
#
# [8 rows x 57 columns]

# %% [markdown]
# #Regression data visualization#
#
# Median age vs total deaths per million

# %%
# cleaning up the data
data_mod = data_orig.dropna(how='any', subset=['location', 'median_age', 'total_deaths_per_million'])
#check if there's any missing values
data_mod[['location', 'median_age', 'total_deaths_per_million']].isnull().any()
# Out:
# location                    False
# median_age                  False
# total_deaths_per_million    False
# dtype: bool

# %%
# grouping the total_values by country and assign mean total deaths and median age
med_age_subset = data_mod.groupby('location')[['median_age', 'total_deaths_per_million']].mean()
med_age_subset.head(10)
# Out:
#                      median_age  total_deaths_per_million
# location
# Afghanistan                18.6                 53.456353
# Albania                    38.0                375.207983
# Algeria                    29.1                 49.550296
# Angola                     16.8                 11.274956
# Antigua and Barbuda        32.1                150.321291
# Argentina                  31.9                818.558620
# Armenia                    35.7                744.234810
# Australia                  37.9                 24.969456
# Austria                    44.4                532.033429
# Azerbaijan                 32.4                206.139368

# %%
# setting variables
y = med_age_subset['total_deaths_per_million']
x1 = med_age_subset['median_age']

# %%
# plot
plt.scatter(x1, y)
plt.ylabel('total_deaths/million', fontsize=20)
plt.xlabel('median_age', fontsize=20)
plt.ylim(0, 1500)
plt.show()

# %%
# visualizing statistics too
x = sm.add_constant(x1)
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     total_deaths_per_million   R-squared:                       0.255
# Model:                                  OLS   Adj. R-squared:                  0.251
# Method:                       Least Squares   F-statistic:                     61.04
# Date:                      Sat, 14 Aug 2021   Prob (F-statistic):           4.67e-13
# Time:                              20:47:36   Log-Likelihood:                -1300.0
# No. Observations:                       180   AIC:                             2604.
# Df Residuals:                           178   BIC:                             2610.
# Df Model:                                 1
# Covariance Type:                  nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -353.9164     86.124     -4.109      0.000    -523.871    -183.962
# median_age    21.2335      2.718      7.813      0.000      15.870      26.597
# ==============================================================================
# Omnibus:                      153.711   Durbin-Watson:                   2.135
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3309.806
# Skew:                           2.961   Prob(JB):                         0.00
# Kurtosis:                      23.155   Cond. No.                         110.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ##Regression Model##
#
# median age vs total deaths/million

# %%
#reshepaing the x values to 2D array for the ML model
x_matrix = x1.values.reshape(-1,1)

# %%
#creating the simple linear regression model
median_age_model = LinearRegression()
median_age_model.fit(x_matrix, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# prediction
new_data = pd.DataFrame(data=[20, 30, 50], columns=['median_age'])
median_age_model.predict(new_data)
# Out:
# array([ 70.75283832, 283.08748183, 707.75676884])

# %%
#R-square calculation
median_age_model.score(x_matrix, y)
# Out:
# 0.25534733543590127
